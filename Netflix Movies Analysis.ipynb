# %%
#Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing The Csv File

df = pd.read_csv(r"D:\Data Analysis Project\Python Project\mymoviedb.csv", engine='python')

# %%
df.head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954       8940
# 1  In his second year of fighting crime, Batman u...    3827.658       1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087        122
# 3  The tale of an extraordinary family, the Madri...    2402.201       5076
# 4  As a collection of history's worst tyrants and...    1895.511       1793
#
#   Vote_Average Original_Language                               Genre  \
# 0          8.3                en  Action, Adventure, Science Fiction
# 1          8.1                en            Crime, Mystery, Thriller
# ...

# %%
#Getting the information about the Columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9837 non-null   object
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   object
#  5   Vote_Average       9827 non-null   object
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 691.8+ KB

# %%
df['Genre'].head()
# Out:
# 0    Action, Adventure, Science Fiction
# 1              Crime, Mystery, Thriller
# 2                              Thriller
# 3    Animation, Comedy, Family, Fantasy
# 4      Action, Adventure, Thriller, War
# Name: Genre, dtype: object

# %%
#Checking Duplicate Records

df.duplicated().sum()
# Out:
# 0

# %%
#Changing Datatype for 'Vote_Count' and 'Vote_Average' from object to Numeric

df['Vote_Count'] = pd.to_numeric(df['Vote_Count'], errors='coerce')
df['Vote_Average'] = pd.to_numeric(df['Vote_Average'], errors='coerce')

# %%
df.describe()
# Out:
#         Popularity    Vote_Count  Vote_Average
# count  9827.000000   9826.000000   9826.000000
# mean     40.320570   1392.943721      6.439467
# std     108.874308   2611.303856      1.129797
# min       7.100000      0.000000      0.000000
# 25%      16.127500    146.000000      5.900000
# 50%      21.191000    444.000000      6.500000
# 75%      35.174500   1376.000000      7.100000
# max    5083.954000  31077.000000     10.000000

# %%
#Changing Datatype for 'Release_Date' from Object to Datetime

df['Release_Date'] = pd.to_datetime(df['Release_Date'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   datetime64[ns]
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9826 non-null   float64
#  5   Vote_Average       9826 non-null   float64
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 691.8+ KB

# %%
df.head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 1  In his second year of fighting crime, Batman u...    3827.658      1151.0
# 2  Stranded at a rest stop in the mountains durin...    2618.087       122.0
# 3  The tale of an extraordinary family, the Madri...    2402.201      5076.0
# 4  As a collection of history's worst tyrants and...    1895.511      1793.0
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
#Extracting Only Year from 'Release_Date'

df['Release_Date']=df['Release_Date'].dt.year

# %%
df.head()
# Out:
#    Release_Date                    Title  \
# 0        2021.0  Spider-Man: No Way Home
# 1        2022.0               The Batman
# 2        2022.0                  No Exit
# 3        2021.0                  Encanto
# 4        2021.0           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 1  In his second year of fighting crime, Batman u...    3827.658      1151.0
# 2  Stranded at a rest stop in the mountains durin...    2618.087       122.0
# 3  The tale of an extraordinary family, the Madri...    2402.201      5076.0
# 4  As a collection of history's worst tyrants and...    1895.511      1793.0
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
# Filling specific date values in place of 'NA' in 'Release_Date' and changing datatype to int

df['Release_Date'] = df['Release_Date'].fillna(0).astype(int)

# %%
df.head()
# Out:
#    Release_Date                    Title  \
# 0          2021  Spider-Man: No Way Home
# 1          2022               The Batman
# 2          2022                  No Exit
# 3          2021                  Encanto
# 4          2021           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 1  In his second year of fighting crime, Batman u...    3827.658      1151.0
# 2  Stranded at a rest stop in the mountains durin...    2618.087       122.0
# 3  The tale of an extraordinary family, the Madri...    2402.201      5076.0
# 4  As a collection of history's worst tyrants and...    1895.511      1793.0
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9837 non-null   int32
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9826 non-null   float64
#  5   Vote_Average       9826 non-null   float64
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: float64(3), int32(1), object(5)
# memory usage: 653.4+ KB

# %%
# Removing Unwanted Columns

cols=['Overview','Original_Language','Poster_Url']
df.drop(cols,axis=1,inplace=True)
df.columns
# Out:
# Index(['Release_Date', 'Title', 'Popularity', 'Vote_Count', 'Vote_Average',
#        'Genre'],
#       dtype='object')

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954      8940.0
# 1          2022               The Batman    3827.658      1151.0
# 2          2022                  No Exit    2618.087       122.0
# 3          2021                  Encanto    2402.201      5076.0
# 4          2021           The King's Man    1895.511      1793.0
#
#    Vote_Average                               Genre
# 0           8.3  Action, Adventure, Science Fiction
# 1           8.1            Crime, Mystery, Thriller
# 2           6.3                            Thriller
# 3           7.7  Animation, Comedy, Family, Fantasy
# 4           7.0    Action, Adventure, Thriller, War

# %% [markdown]
# # Categorizing 'Vote_Average' Column

# %% [markdown]
#     Categorizing the 'Vote_Average' column into 4 categories : 'Popular', 'Avergae', 'Below_Avg', and 'Not_Popular' to describe it more using categorize_col() function provided below :

# %%
def categorize_col(df,col,labels):
    edges=[df[col].describe()['min'],
          df[col].describe()['25%'],
          df[col].describe()['50%'],
          df[col].describe()['75%'],
          df[col].describe()['max']]
    df[col]=pd.cut(df[col],edges,labels=labels,duplicates='drop')
    return df

# %%
labels=['Not Popular','Below Avg','Average','Popular']
categorize_col(df,'Vote_Average',labels)
df['Vote_Average'].unique()
# Out:
# ['Popular', 'Below Avg', 'Average', 'Not Popular', NaN]
# Categories (4, object): ['Not Popular' < 'Below Avg' < 'Average' < 'Popular']

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954      8940.0      Popular
# 1          2022               The Batman    3827.658      1151.0      Popular
# 2          2022                  No Exit    2618.087       122.0    Below Avg
# 3          2021                  Encanto    2402.201      5076.0      Popular
# 4          2021           The King's Man    1895.511      1793.0      Average
#
#                                 Genre
# 0  Action, Adventure, Science Fiction
# 1            Crime, Mystery, Thriller
# 2                            Thriller
# 3  Animation, Comedy, Family, Fantasy
# 4    Action, Adventure, Thriller, War

# %%
df['Vote_Average'].value_counts()
# Out:
# Vote_Average
# Not Popular    2467
# Popular        2450
# Average        2411
# Below Avg      2398
# Name: count, dtype: int64

# %%
# Checking for 'NA' values

df.isna().sum()
# Out:
# Release_Date      0
# Title             9
# Popularity       10
# Vote_Count       11
# Vote_Average    111
# Genre            11
# dtype: int64

# %%
# Removing 'NA' values from the dataframe

df.dropna(inplace=True)
df.isna().sum()
# Out:
# Release_Date    0
# Title           0
# Popularity      0
# Vote_Count      0
# Vote_Average    0
# Genre           0
# dtype: int64

# %% [markdown]
# # Splitting 'Genre' Column into a list

# %% [markdown]
#     We would split Genres into a list and then explode our dataframe to have only one genre per row for each movie

# %%
df['Genre']=df['Genre'].str.split(', ')
df=df.explode('Genre').reset_index(drop=True)
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954      8940.0      Popular
# 1          2021  Spider-Man: No Way Home    5083.954      8940.0      Popular
# 2          2021  Spider-Man: No Way Home    5083.954      8940.0      Popular
# 3          2022               The Batman    3827.658      1151.0      Popular
# 4          2022               The Batman    3827.658      1151.0      Popular
#
#              Genre
# 0           Action
# 1        Adventure
# 2  Science Fiction
# 3            Crime
# 4          Mystery

# %%
# Casting 'Genre' Column into category

df['Genre']=df['Genre'].astype('category')
df['Genre'].dtypes
# Out:
# CategoricalDtype(categories=['Action', 'Adventure', 'Animation', 'Comedy', 'Crime',
#                   'Documentary', 'Drama', 'Family', 'Fantasy', 'History',
#                   'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction',
#                   'TV Movie', 'Thriller', 'War', 'Western'],
# , ordered=False)

# %%
# Data has exploded from 9837 to 25551 records

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25551 entries, 0 to 25550
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Release_Date  25551 non-null  int32
#  1   Title         25551 non-null  object
#  2   Popularity    25551 non-null  float64
#  3   Vote_Count    25551 non-null  float64
#  4   Vote_Average  25551 non-null  category
#  5   Genre         25551 non-null  category
# dtypes: category(2), float64(2), int32(1), object(1)
# memory usage: 749.6+ KB

# %%
df.nunique()
# Out:
# Release_Date     100
# Title           9414
# Popularity      8087
# Vote_Count      3265
# Vote_Average       4
# Genre             19
# dtype: int64

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954      8940.0      Popular
# 1          2021  Spider-Man: No Way Home    5083.954      8940.0      Popular
# 2          2021  Spider-Man: No Way Home    5083.954      8940.0      Popular
# 3          2022               The Batman    3827.658      1151.0      Popular
# 4          2022               The Batman    3827.658      1151.0      Popular
#
#              Genre
# 0           Action
# 1        Adventure
# 2  Science Fiction
# 3            Crime
# 4          Mystery

# %% [markdown]
# # Data Visualization

# %%
sns.set_style('whitegrid')

# %% [markdown]
# # Most frequent Genre of movies released on Netflix

# %%
df['Genre'].describe()
# Out:
# count     25551
# unique       19
# top       Drama
# freq       3715
# Name: Genre, dtype: object

# %%
sns.catplot(y='Genre',data=df,kind='count',order=df['Genre'].value_counts().index,color='#4287f5')
plt.title("Genre Column Distribution")
plt.show()
# Out:
# C:\Users\Manish Banjara\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Highest votes in 'Vote_Average' Column

# %%
sns.catplot(y='Vote_Average',data=df,kind='count',order=df['Vote_Average'].value_counts().index,color='#4287f5')
plt.title("Votes Distribution")
plt.show()
# Out:
# C:\Users\Manish Banjara\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Which movie got the highest popularity and what it's Genre..?

# %%
df[df['Popularity']==df['Popularity'].max()]
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954      8940.0      Popular
# 1          2021  Spider-Man: No Way Home    5083.954      8940.0      Popular
# 2          2021  Spider-Man: No Way Home    5083.954      8940.0      Popular
#
#              Genre
# 0           Action
# 1        Adventure
# 2  Science Fiction

# %% [markdown]
# # Which movie got the lowest popularity and what it's Genre..?

# %%
df[df['Popularity']==df['Popularity'].min()]
# Out:
#        Release_Date                                 Title  Popularity  \
# 25545          2021  The United States vs. Billie Holiday      13.354
# 25546          2021  The United States vs. Billie Holiday      13.354
# 25547          2021  The United States vs. Billie Holiday      13.354
# 25548          1984                               Threads      13.354
# 25549          1984                               Threads      13.354
# 25550          1984                               Threads      13.354
#
#        Vote_Count Vote_Average            Genre
# 25545       152.0      Average            Music
# 25546       152.0      Average            Drama
# 25547       152.0      Average          History
# 25548       186.0      Popular              War
# 25549       186.0      Popular            Drama
# 25550       186.0      Popular  Science Fiction

# %% [markdown]
# # Year with most filmmed movies

# %%
df['Release_Date'].hist()
plt.title("Release Year Column Distribution")
plt.show()

# %% [markdown]
# # Conclusion :
#
#  Q1 : What is the most frequent genre in the dataset..?
#  Ans : Drama genre is the most frequent genre in the dataset and has appeared more than 14% of the times among 19 other genres.
#
# Q2 : What genre has highest votes..?
# Ans : We have 25.5% of our dataset with popular votes (6519 rows). Drama again gets the highest popularity among fans by being having more than 18.5% of movies popularity
#
# Q3 : Which movie got the highest popularity and what it's genre..?
# Ans : "Spider-Man : No Way Home" has the highest popularity rate in the dataset and it has genre of Action, Adventure and Science Fiction.
#
# Q4 : Which movie got the lowest popularity and what it's genre..?
# Ans : "The United States" and "Threads" has the lowest popularity rate in the dataset and it has genre of Music, Drama, War, Sci-fi and History.
#
# Q5 : Which year has the most filmed movies..?
# Ans : 2020 has the highest filming rate in the dataset.
